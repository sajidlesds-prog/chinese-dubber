# %%
# Setup
# !git clone https://github.com/YOUR_FORK/pyvideotrans
# %cd pyvideotrans
# !pip install -r requirements.txt -q
# !pip install googletrans==4.0.0rc1 httpx==0.13.3 -q
# !apt-get install ffmpeg -qq
print("✅ Setup complete")

# %% [markdown]
# ## Upload your customized files
#
# Replace these files with our customized versions from GitHub or manual upload:
#
# - `videotrans/configure/config.py`
# - `videotrans/process/stt_fun.py`
# - `videotrans/tts/_base.py`
# - `videotrans/util/help_misc.py`
# - `videotrans/translator/_google.py`
# - `colab_runner.py`

# %%
# Upload movie & run
import os
os.makedirs("/content/input_videos", exist_ok=True)
os.makedirs("/content/dubbed_output", exist_ok=True)
print("Upload your .mp4 files to /content/input_videos/")
print("Then run the next cell")

# %%
# Run dubbing
# !python colab_runner.py

# %%
# Download results
from google.colab import files
import os
for f in os.listdir("/content/dubbed_output"):
    if f.endswith(".mp4"):
        files.download(f"/content/dubbed_output/{f}")
